# %%
import pandas as pd 
import numpy as np

# %%
reg = pd.read_csv('./data/md_ev_reg_zip.csv')
stations = pd.read_csv('./data/md_ev_stations.csv')

# %%
stations = stations[['Program','Station Name','ZipCode','Access']]
stations.head()
# Out:
#                                              Program  \
# 0                 Electric Vehicle Charging Stations
# 1  Electric Vehicle Supply Equipment Tax Credit P...
# 2                 Electric Vehicle Charging Stations
# 3                 Electric Vehicle Charging Stations
# 4                 Electric Vehicle Charging Stations
#
#                      Station Name  ZipCode  Access
# 0  Antwerpen Nissan - Clarksville    21029  Public
# 1                  Capitol Fisker    20770  Public
# 2                 Hamilton Nissan    21740  Public
# 3                       Walgreens    21213  Public
# 4     The Frederick Motor Company    21702  Public

# %%
reg.head()
# Out:
#   Year_Month Fuel_Category Zip_Code  Count
# 0    2020/07      Electric    19973      1
# 1    2020/07      Electric    20601     21
# 2    2020/07      Electric    20602     26
# 3    2020/07      Electric    20603     54
# 4    2020/07      Electric    20607     35

# %%
reg.loc[reg['Zip_Code'].isin(['UNKNOWN', 'VA', 'NY','RESTO','2001+']), 'Zip_Code'] = '0'
reg['Zip_Code'] = reg['Zip_Code'].fillna(0)
reg['Zip_Code'] = reg['Zip_Code'].astype(int)

# %%
reg
# Out:
#       Year_Month   Fuel_Category  Zip_Code  Count
# 0        2020/07        Electric     19973      1
# 1        2020/07        Electric     20601     21
# 2        2020/07        Electric     20602     26
# 3        2020/07        Electric     20603     54
# 4        2020/07        Electric     20607     35
# ...          ...             ...       ...    ...
# 80710    2025/03  Plug-In Hybrid     95628      1
# 80711    2025/03  Plug-In Hybrid     98112      1
# 80712    2025/03  Plug-In Hybrid     98370      1
# 80713    2025/03  Plug-In Hybrid     98626      1
# 80714    2025/03  Plug-In Hybrid     99577      1
#
# [80715 rows x 4 columns]

# %%
merged = pd.merge(reg, stations, how='left', left_on='Zip_Code', right_on='ZipCode')
merged.head()
# Out:
#   Year_Month Fuel_Category  Zip_Code  Count  \
# 0    2020/07      Electric     19973      1
# 1    2020/07      Electric     20601     21
# 2    2020/07      Electric     20601     21
# 3    2020/07      Electric     20601     21
# 4    2020/07      Electric     20602     26
#
#                                              Program  \
# 0                                                NaN
# 1  Electric Vehicle Supply Equipment Tax Credit P...
# 2                 Electric Vehicle Charging Stations
# 3     Electric Vehicle Infrastructure Program (EVIP)
# 4                 Electric Vehicle Charging Stations
#
#                                         Station Name  ZipCode  Access
# 0                                                NaN      NaN     NaN
# 1                                  Sheehy Auto Store  20601.0  Public
# 2                                       Waldorf Ford  20601.0  Public
# 3                              Charles County Hilton  20601.0  Public
# 4  Charles County Public Library - PD Brown Memor...  20602.0  Public

# %%
merged['Year_Month'] = pd.to_datetime(merged['Year_Month'], format='%Y/%m')

# %%
merged['year'] = merged['Year_Month'].dt.year
merged['month'] = merged['Year_Month'].dt.month

# %%
merged['Fuel_Category'] = merged['Fuel_Category'].apply(lambda x: 'BEV' if x=='Electric' else 'PHEV')

# %%
merged.dropna(axis=0)
# Out:
#       Year_Month Fuel_Category  Zip_Code  Count  \
# 1     2020-07-01           BEV     20601     21
# 2     2020-07-01           BEV     20601     21
# 3     2020-07-01           BEV     20601     21
# 4     2020-07-01           BEV     20602     26
# 5     2020-07-01           BEV     20602     26
# ...          ...           ...       ...    ...
# 98715 2025-03-01          PHEV     21771    220
# 98725 2025-03-01          PHEV     21784    233
# 98735 2025-03-01          PHEV     21801    126
# 98736 2025-03-01          PHEV     21804     76
# 98737 2025-03-01          PHEV     21811    117
#
#                                                  Program  \
# 1      Electric Vehicle Supply Equipment Tax Credit P...
# 2                     Electric Vehicle Charging Stations
# 3         Electric Vehicle Infrastructure Program (EVIP)
# 4                     Electric Vehicle Charging Stations
# 5                     Electric Vehicle Charging Stations
# ...                                                  ...
# 98715                 Electric Vehicle Charging Stations
# 98725                 Electric Vehicle Charging Stations
# 98735                       Biodiesel Refueling Stations
# 98736                       Biodiesel Refueling Stations
# 98737                       Biodiesel Refueling Stations
#
#                                             Station Name  ZipCode  Access  \
# 1                                      Sheehy Auto Store  20601.0  Public
# 2                                           Waldorf Ford  20601.0  Public
# 3                                  Charles County Hilton  20601.0  Public
# 4      Charles County Public Library - PD Brown Memor...  20602.0  Public
# 5                                              Walgreens  20602.0  Public
# ...                                                  ...      ...     ...
# 98715                                       Century Ford  21771.0  Public
# 98725                                          Walgreens  21784.0  Public
# 98735                            Cato Pacific Pride Fuel  21801.0  Public
# 98736                            Cato Pacific Pride Fuel  21804.0  Public
# 98737                                  Cropper Oil & Gas  21811.0  Public
#
#        year  month
# 1      2020      7
# 2      2020      7
# 3      2020      7
# 4      2020      7
# 5      2020      7
# ...     ...    ...
# 98715  2025      3
# 98725  2025      3
# 98735  2025      3
# 98736  2025      3
# 98737  2025      3
#
# [25239 rows x 10 columns]

# %%
simplified = merged.groupby(['year', 'month', 'Zip_Code', 'Fuel_Category']).agg({'Count': 'first'}).reset_index()
simplified
# Out:
#        year  month  Zip_Code Fuel_Category  Count
# 0      2020      7         0           BEV     28
# 1      2020      7         0          PHEV     18
# 2      2020      7     19973           BEV      1
# 3      2020      7     19973          PHEV      1
# 4      2020      7     20601           BEV     21
# ...     ...    ...       ...           ...    ...
# 80700  2025      3     98626          PHEV      1
# 80701  2025      3     99504           BEV      1
# 80702  2025      3     99505           BEV      1
# 80703  2025      3     99577          PHEV      1
# 80704  2025      3     99615           BEV      1
#
# [80705 rows x 5 columns]

# %%
monthly = merged.groupby(['Year_Month','Fuel_Category']).agg({'Count': 'sum'}).reset_index()
monthly
# Out:
#     Year_Month Fuel_Category   Count
# 0   2020-07-01           BEV   36962
# 1   2020-07-01          PHEV   24286
# 2   2020-08-01           BEV   37895
# 3   2020-08-01          PHEV   24694
# 4   2020-09-01           BEV   38546
# ..         ...           ...     ...
# 109 2025-01-01          PHEV   84759
# 110 2025-02-01           BEV  213450
# 111 2025-02-01          PHEV   85559
# 112 2025-03-01           BEV  217665
# 113 2025-03-01          PHEV   87110
#
# [114 rows x 3 columns]

# %%
import plotly.express as px

# %%
px.line(monthly, x='Year_Month', y='Count', color='Fuel_Category', title='Monthly EV Registrations in Maryland by Fuel Type').show()

# %% [markdown]
# Now we cross-reference with [this database](https://simplemaps.com/data/us-zips.)

# %%
md_only = merged.dropna(axis=0)
md_only
# Out:
#       Year_Month Fuel_Category  Zip_Code  Count  \
# 1     2020-07-01           BEV     20601     21
# 2     2020-07-01           BEV     20601     21
# 3     2020-07-01           BEV     20601     21
# 4     2020-07-01           BEV     20602     26
# 5     2020-07-01           BEV     20602     26
# ...          ...           ...       ...    ...
# 98715 2025-03-01          PHEV     21771    220
# 98725 2025-03-01          PHEV     21784    233
# 98735 2025-03-01          PHEV     21801    126
# 98736 2025-03-01          PHEV     21804     76
# 98737 2025-03-01          PHEV     21811    117
#
#                                                  Program  \
# 1      Electric Vehicle Supply Equipment Tax Credit P...
# 2                     Electric Vehicle Charging Stations
# 3         Electric Vehicle Infrastructure Program (EVIP)
# 4                     Electric Vehicle Charging Stations
# 5                     Electric Vehicle Charging Stations
# ...                                                  ...
# 98715                 Electric Vehicle Charging Stations
# 98725                 Electric Vehicle Charging Stations
# 98735                       Biodiesel Refueling Stations
# 98736                       Biodiesel Refueling Stations
# 98737                       Biodiesel Refueling Stations
#
#                                             Station Name  ZipCode  Access  \
# 1                                      Sheehy Auto Store  20601.0  Public
# 2                                           Waldorf Ford  20601.0  Public
# 3                                  Charles County Hilton  20601.0  Public
# 4      Charles County Public Library - PD Brown Memor...  20602.0  Public
# 5                                              Walgreens  20602.0  Public
# ...                                                  ...      ...     ...
# 98715                                       Century Ford  21771.0  Public
# 98725                                          Walgreens  21784.0  Public
# 98735                            Cato Pacific Pride Fuel  21801.0  Public
# 98736                            Cato Pacific Pride Fuel  21804.0  Public
# 98737                                  Cropper Oil & Gas  21811.0  Public
#
#        year  month
# 1      2020      7
# 2      2020      7
# 3      2020      7
# 4      2020      7
# 5      2020      7
# ...     ...    ...
# 98715  2025      3
# 98725  2025      3
# 98735  2025      3
# 98736  2025      3
# 98737  2025      3
#
# [25239 rows x 10 columns]

# %%
zips = pd.read_csv('./data/uszips.csv')
zips
# Out:
#          zip       lat        lng         city state_id   state_name  zcta  \
# 0        601  18.18027  -66.75266     Adjuntas       PR  Puerto Rico  True
# 1        602  18.36075  -67.17541       Aguada       PR  Puerto Rico  True
# 2        603  18.45744  -67.12225    Aguadilla       PR  Puerto Rico  True
# 3        606  18.16585  -66.93716      Maricao       PR  Puerto Rico  True
# 4        610  18.29110  -67.12243       Anasco       PR  Puerto Rico  True
# ...      ...       ...        ...          ...      ...          ...   ...
# 33778  99923  55.98043 -130.03803        Hyder       AK       Alaska  True
# 33779  99925  55.55398 -132.96276      Klawock       AK       Alaska  True
# 33780  99926  55.12617 -131.48928   Metlakatla       AK       Alaska  True
# 33781  99927  56.33305 -133.60044  Point Baker       AK       Alaska  True
# 33782  99929  56.36089 -132.00635     Wrangell       AK       Alaska  True
#
#        parent_zcta  population  density  county_fips            county_name  \
# 0              NaN     16721.0    100.2        72001               Adjuntas
# 1              NaN     37510.0    477.6        72003                 Aguada
# 2              NaN     48317.0    543.1        72005              Aguadilla
# 3              NaN      5435.0     47.3        72093                Maricao
# 4              NaN     25413.0    264.4        72011                 Añasco
# ...            ...         ...      ...          ...                    ...
# 33778          NaN        25.0      0.6         2198  Prince of Wales-Hyder
# 33779          NaN       854.0      6.1         2198  Prince of Wales-Hyder
# 33780          NaN      1385.0      4.0         2198  Prince of Wales-Hyder
# 33781          NaN        18.0      1.5         2198  Prince of Wales-Hyder
# 33782          NaN      2105.0      0.3         2275               Wrangell
#
#                                           county_weights  \
# 0                        {"72001": 98.74, "72141": 1.26}
# 1                                         {"72003": 100}
# 2                        {"72005": 99.76, "72099": 0.24}
# 3        {"72093": 82.27, "72153": 11.66, "72121": 6.06}
# 4      {"72011": 96.71, "72099": 2.82, "72083": 0.37,...
# ...                                                  ...
# 33778                                     {"02198": 100}
# 33779                                     {"02198": 100}
# 33780                                     {"02198": 100}
# 33781                                     {"02198": 100}
# 33782                                     {"02275": 100}
#
#                     county_names_all          county_fips_all  imprecise  \
# 0                    Adjuntas|Utuado              72001|72141      False
# 1                             Aguada                    72003      False
# 2                     Aguadilla|Moca              72005|72099      False
# 3        Maricao|Yauco|Sabana Grande        72093|72153|72121      False
# 4      Añasco|Moca|Las Marías|Aguada  72011|72099|72083|72003      False
# ...                              ...                      ...        ...
# 33778          Prince of Wales-Hyder                    02198      False
# 33779          Prince of Wales-Hyder                    02198      False
# 33780          Prince of Wales-Hyder                    02198      False
# 33781          Prince of Wales-Hyder                    02198      False
# 33782                       Wrangell                    02275      False
#
#        military             timezone
# 0         False  America/Puerto_Rico
# 1         False  America/Puerto_Rico
# 2         False  America/Puerto_Rico
# 3         False  America/Puerto_Rico
# 4         False  America/Puerto_Rico
# ...         ...                  ...
# 33778     False        America/Sitka
# 33779     False        America/Sitka
# 33780     False   America/Metlakatla
# 33781     False        America/Sitka
# 33782     False        America/Sitka
#
# [33783 rows x 18 columns]

# %%
zips = zips[['zip', 'lat', 'lng', 'city', 'state_id','population','density']]

# %%
with_zip_stats = pd.merge(md_only, zips, how='left', left_on='Zip_Code', right_on='zip')

# %%
with_zip_stats
# Out:
#       Year_Month Fuel_Category  Zip_Code  Count  \
# 0     2020-07-01           BEV     20601     21
# 1     2020-07-01           BEV     20601     21
# 2     2020-07-01           BEV     20601     21
# 3     2020-07-01           BEV     20602     26
# 4     2020-07-01           BEV     20602     26
# ...          ...           ...       ...    ...
# 25234 2025-03-01          PHEV     21771    220
# 25235 2025-03-01          PHEV     21784    233
# 25236 2025-03-01          PHEV     21801    126
# 25237 2025-03-01          PHEV     21804     76
# 25238 2025-03-01          PHEV     21811    117
#
#                                                  Program  \
# 0      Electric Vehicle Supply Equipment Tax Credit P...
# 1                     Electric Vehicle Charging Stations
# 2         Electric Vehicle Infrastructure Program (EVIP)
# 3                     Electric Vehicle Charging Stations
# 4                     Electric Vehicle Charging Stations
# ...                                                  ...
# 25234                 Electric Vehicle Charging Stations
# 25235                 Electric Vehicle Charging Stations
# 25236                       Biodiesel Refueling Stations
# 25237                       Biodiesel Refueling Stations
# 25238                       Biodiesel Refueling Stations
#
#                                             Station Name  ZipCode  Access  \
# 0                                      Sheehy Auto Store  20601.0  Public
# 1                                           Waldorf Ford  20601.0  Public
# 2                                  Charles County Hilton  20601.0  Public
# 3      Charles County Public Library - PD Brown Memor...  20602.0  Public
# 4                                              Walgreens  20602.0  Public
# ...                                                  ...      ...     ...
# 25234                                       Century Ford  21771.0  Public
# 25235                                          Walgreens  21784.0  Public
# 25236                            Cato Pacific Pride Fuel  21801.0  Public
# 25237                            Cato Pacific Pride Fuel  21804.0  Public
# 25238                                  Cropper Oil & Gas  21811.0  Public
#
#        year  month      zip       lat       lng        city state_id  \
# 0      2020      7  20601.0  38.61863 -76.85715     Waldorf       MD
# 1      2020      7  20601.0  38.61863 -76.85715     Waldorf       MD
# 2      2020      7  20601.0  38.61863 -76.85715     Waldorf       MD
# 3      2020      7  20602.0  38.58335 -76.89466     Waldorf       MD
# 4      2020      7  20602.0  38.58335 -76.89466     Waldorf       MD
# ...     ...    ...      ...       ...       ...         ...      ...
# 25234  2025      3  21771.0  39.39550 -77.15869  Mount Airy       MD
# 25235  2025      3  21784.0  39.40087 -76.97260  Sykesville       MD
# 25236  2025      3  21801.0  38.38106 -75.64073   Salisbury       MD
# 25237  2025      3  21804.0  38.31726 -75.53673   Salisbury       MD
# 25238  2025      3  21811.0  38.31977 -75.22024      Berlin       MD
#
#        population  density
# 0         27340.0    220.7
# 1         27340.0    220.7
# 2         27340.0    220.7
# 3         29425.0    784.8
# 4         29425.0    784.8
# ...           ...      ...
# 25234     32827.0    141.6
# 25235     37813.0    260.1
# 25236     30063.0    289.4
# 25237     39461.0    222.1
# 25238     24263.0     92.3
#
# [25239 rows x 17 columns]

# %%
path_1901 = './data/1901.csv'

def proc_df(path):
    df = pd.read_csv(path, skiprows=1)
    drop_col = []
    for col in df.columns:
        new_name = col.replace('!!',' ')
        if 'Margin of Error' in new_name or 'PERCENT ALLOCATED' in new_name:
            drop_col.append(new_name)
        df.rename(columns={col: new_name}, inplace=True)
    df.drop(columns=drop_col, inplace=True)
    df['Geographic Area Name'] = df['Geographic Area Name'].str.replace('ZCTA5 ','').astype(int)
    df.drop(columns = ['Geography'], inplace=True)
    df.dropna(axis=1, inplace=True)
    df = df.rename(columns={'Geographic Area Name': 'Zip_Code'})
    return df

# %%
df1901 = proc_df(path_1901)
df1901.head()
# Out:
#    Zip_Code  Estimate Households Total  \
# 0     19973                       9927
# 1     20601                      10011
# 2     20602                      10659
# 3     20603                      11518
# 4     20606                         88
#
#   Estimate Households Total Less than $10,000  \
# 0                                         6.1
# 1                                         3.1
# 2                                         5.3
# 3                                         2.0
# 4                                         0.0
#
#   Estimate Households Total $10,000 to $14,999  \
# 0                                          4.6
# 1                                          2.4
# 2                                          3.1
# 3                                          1.8
# 4                                          0.0
#
#   Estimate Households Total $15,000 to $24,999  \
# 0                                          7.0
# 1                                          2.6
# 2                                          2.9
# 3                                          3.2
# 4                                          0.0
#
#   Estimate Households Total $25,000 to $34,999  \
# 0                                          8.6
# 1                                          2.3
# 2                                          2.8
# 3                                          3.0
# 4                                          0.0
#
#   Estimate Households Total $35,000 to $49,999  \
# 0                                         15.0
# 1                                          4.7
# 2                                          6.1
# 3                                          4.0
# 4                                          0.0
#
#   Estimate Households Total $50,000 to $74,999  \
# 0                                         17.0
# 1                                          9.3
# 2                                         12.6
# 3                                          8.3
# 4                                         29.5
#
#   Estimate Households Total $75,000 to $99,999  \
# 0                                         11.4
# 1                                         15.5
# 2                                         10.9
# 3                                         11.0
# 4                                         36.4
#
#   Estimate Households Total $100,000 to $149,999  ...  \
# 0                                           15.3  ...
# 1                                           29.1  ...
# 2                                           27.6  ...
# 3                                           21.8  ...
# 4                                            0.0  ...
#
#   Estimate Nonfamily households Total $15,000 to $24,999  \
# 0                                               11.9
# 1                                                7.5
# 2                                                5.8
# 3                                                6.8
# 4                                                0.0
#
#   Estimate Nonfamily households Total $25,000 to $34,999  \
# 0                                               16.5
# 1                                                3.9
# 2                                                5.6
# 3                                                6.7
# 4                                                0.0
#
#   Estimate Nonfamily households Total $35,000 to $49,999  \
# 0                                               18.8
# 1                                                8.9
# 2                                               10.1
# 3                                                7.2
# 4                                                0.0
#
#   Estimate Nonfamily households Total $50,000 to $74,999  \
# 0                                               12.2
# 1                                               10.6
# 2                                               18.9
# 3                                               12.6
# 4                                                0.0
#
#    Estimate Nonfamily households Total $75,000 to $99,999  \
# 0                                                9.6
# 1                                               21.9
# 2                                               10.5
# 3                                               13.0
# 4                                               86.5
#
#   Estimate Nonfamily households Total $100,000 to $149,999  \
# 0                                                2.7
# 1                                               24.1
# 2                                               24.2
# 3                                               21.1
# 4                                                0.0
#
#   Estimate Nonfamily households Total $150,000 to $199,999  \
# 0                                                3.9
# 1                                                8.5
# 2                                                5.0
# 3                                               15.8
# 4                                               13.5
#
#   Estimate Nonfamily households Total $200,000 or more  \
# 0                                                2.6
# 1                                                5.0
# 2                                                1.4
# 3                                                6.4
# 4                                                0.0
#
#   Estimate Nonfamily households Median income (dollars)  \
# 0                                              34794
# 1                                              83052
# 2                                              67977
# 3                                              81921
# 4                                                  -
#
#   Estimate Nonfamily households Mean income (dollars)
# 0                                              48087
# 1                                              92628
# 2                                              69240
# 3                                              93785
# 4                                                  N
#
# [5 rows x 53 columns]

# %%
df1903 = proc_df('./data/1903.csv')
df1903.head()
# Out:
#    Zip_Code  \
# 0     19973
# 1     20601
# 2     20602
# 3     20603
# 4     20606
#
#    Estimate Number HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER Households  \
# 0                                               9927
# 1                                              10011
# 2                                              10659
# 3                                              11518
# 4                                                 88
#
#    Estimate Number HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER Households One race-- White  \
# 0                                               6823
# 1                                               2825
# 2                                               2587
# 3                                               2565
# 4                                                 81
#
#    Estimate Number HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER Households One race-- Black or African American  \
# 0                                               2020
# 1                                               5778
# 2                                               6805
# 3                                               7403
# 4                                                  7
#
#    Estimate Number HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER Households One race-- American Indian and Alaska Native  \
# 0                                                  4
# 1                                                 68
# 2                                                 80
# 3                                                  0
# 4                                                  0
#
#    Estimate Number HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER Households One race-- Asian  \
# 0                                                 72
# 1                                                287
# 2                                                235
# 3                                                652
# 4                                                  0
#
#    Estimate Number HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER Households One race-- Native Hawaiian and Other Pacific Islander  \
# 0                                                  0
# 1                                                  4
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Estimate Number HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER Households One race-- Some other race  \
# 0                                                288
# 1                                                370
# 2                                                220
# 3                                                185
# 4                                                  0
#
#    Estimate Number HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER Households Two or more races  \
# 0                                                720
# 1                                                679
# 2                                                732
# 3                                                713
# 4                                                  0
#
#    Estimate Number HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER Households Hispanic or Latino origin (of any race)  \
# 0                                                788
# 1                                                804
# 2                                                744
# 3                                                709
# 4                                                  0
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Estimate Median income (dollars) FAMILY INCOME BY NUMBER OF EARNERS 1 earner  \
# 0                                              54238
# 1                                             101250
# 2                                              76797
# 3                                              93719
# 4                                                  -
#
#    Estimate Median income (dollars) FAMILY INCOME BY NUMBER OF EARNERS 2 earners  \
# 0                                             101864
# 1                                             144789
# 2                                             147642
# 3                                             186288
# 4                                                  -
#
#    Estimate Median income (dollars) FAMILY INCOME BY NUMBER OF EARNERS 3 or more earners  \
# 0                                             139750
# 1                                             180184
# 2                                             173438
# 3                                             228466
# 4                                                  -
#
#    Estimate Median income (dollars) NONFAMILY HOUSEHOLDS Nonfamily households  \
# 0                                              34794
# 1                                              83052
# 2                                              67977
# 3                                              81921
# 4                                                  -
#
#    Estimate Median income (dollars) NONFAMILY HOUSEHOLDS Nonfamily households Female householder  \
# 0                                              32411
# 1                                              89229
# 2                                              71263
# 3                                              79010
# 4                                                  -
#
#    Estimate Median income (dollars) NONFAMILY HOUSEHOLDS Nonfamily households Female householder Living alone  \
# 0                                              31382
# 1                                              85333
# 2                                              61705
# 3                                              72500
# 4                                                  -
#
#    Estimate Median income (dollars) NONFAMILY HOUSEHOLDS Nonfamily households Female householder Not living alone  \
# 0                                                  -
# 1                                             147059
# 2                                             108533
# 3                                             146591
# 4                                                  -
#
#    Estimate Median income (dollars) NONFAMILY HOUSEHOLDS Nonfamily households Male householder  \
# 0                                              37233
# 1                                              77746
# 2                                              64605
# 3                                              84286
# 4                                                  -
#
#    Estimate Median income (dollars) NONFAMILY HOUSEHOLDS Nonfamily households Male householder Living alone  \
# 0                                              36443
# 1                                              66875
# 2                                              55455
# 3                                              79393
# 4                                                  -
#
#    Estimate Median income (dollars) NONFAMILY HOUSEHOLDS Nonfamily households Male householder Not living alone
# 0                                                  -
# 1                                              94516
# 2                                             112857
# 3                                             213393
# 4                                                  -
#
# [5 rows x 121 columns]

# %%
df2503 = proc_df('./data/2503.csv')
df2503.head()
# Out:
#    Zip_Code  Estimate Occupied housing units Occupied housing units  \
# 0     19973                                               9927
# 1     20601                                              10011
# 2     20602                                              10659
# 3     20603                                              11518
# 4     20606                                                 88
#
#    Estimate Occupied housing units Occupied housing units HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2023 INFLATION-ADJUSTED DOLLARS) Less than $5,000  \
# 0                                                419
# 1                                                223
# 2                                                302
# 3                                                112
# 4                                                  0
#
#    Estimate Occupied housing units Occupied housing units HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2023 INFLATION-ADJUSTED DOLLARS) $5,000 to $9,999  \
# 0                                                189
# 1                                                 87
# 2                                                258
# 3                                                113
# 4                                                  0
#
#    Estimate Occupied housing units Occupied housing units HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2023 INFLATION-ADJUSTED DOLLARS) $10,000 to $14,999  \
# 0                                                456
# 1                                                245
# 2                                                330
# 3                                                213
# 4                                                  0
#
#    Estimate Occupied housing units Occupied housing units HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2023 INFLATION-ADJUSTED DOLLARS) $15,000 to $19,999  \
# 0                                                362
# 1                                                 72
# 2                                                176
# 3                                                206
# 4                                                  0
#
#    Estimate Occupied housing units Occupied housing units HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2023 INFLATION-ADJUSTED DOLLARS) $20,000 to $24,999  \
# 0                                                333
# 1                                                191
# 2                                                130
# 3                                                162
# 4                                                  0
#
#    Estimate Occupied housing units Occupied housing units HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2023 INFLATION-ADJUSTED DOLLARS) $25,000 to $34,999  \
# 0                                                853
# 1                                                231
# 2                                                303
# 3                                                341
# 4                                                  0
#
#    Estimate Occupied housing units Occupied housing units HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2023 INFLATION-ADJUSTED DOLLARS) $35,000 to $49,999  \
# 0                                               1487
# 1                                                473
# 2                                                651
# 3                                                465
# 4                                                  0
#
#    Estimate Occupied housing units Occupied housing units HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2023 INFLATION-ADJUSTED DOLLARS) $50,000 to $74,999  \
# 0                                               1688
# 1                                                932
# 2                                               1345
# 3                                                952
# 4                                                 26
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Estimate Percent renter-occupied housing units Occupied housing units MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS $50,000 to $74,999  \
# 0                                               17.0
# 1                                                4.3
# 2                                               16.8
# 3                                               13.9
# 4                                                  -
#
#    Estimate Percent renter-occupied housing units Occupied housing units MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS $50,000 to $74,999 Less than 20 percent  \
# 0                                                0.9
# 1                                                0.0
# 2                                                1.0
# 3                                                0.0
# 4                                                  -
#
#    Estimate Percent renter-occupied housing units Occupied housing units MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS $50,000 to $74,999 20 to 29 percent  \
# 0                                                8.8
# 1                                                0.0
# 2                                                3.5
# 3                                                5.0
# 4                                                  -
#
#   Estimate Percent renter-occupied housing units Occupied housing units MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS $50,000 to $74,999 30 percent or more  \
# 0                                                7.3
# 1                                                4.3
# 2                                               12.4
# 3                                                8.9
# 4                                                  -
#
#    Estimate Percent renter-occupied housing units Occupied housing units MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS $75,000 or more  \
# 0                                               19.6
# 1                                               69.3
# 2                                               47.7
# 3                                               50.7
# 4                                                  -
#
#    Estimate Percent renter-occupied housing units Occupied housing units MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS $75,000 or more Less than 20 percent  \
# 0                                               15.1
# 1                                               21.1
# 2                                               13.0
# 3                                               21.4
# 4                                                  -
#
#    Estimate Percent renter-occupied housing units Occupied housing units MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS $75,000 or more 20 to 29 percent  \
# 0                                                2.3
# 1                                               39.1
# 2                                               31.5
# 3                                               23.2
# 4                                                  -
#
#    Estimate Percent renter-occupied housing units Occupied housing units MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS $75,000 or more 30 percent or more  \
# 0                                                2.2
# 1                                                9.0
# 2                                                3.2
# 3                                                6.1
# 4                                                  -
#
#    Estimate Percent renter-occupied housing units Occupied housing units MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS Zero or negative income  \
# 0                                                0.9
# 1                                                1.8
# 2                                                2.8
# 3                                                0.0
# 4                                                  -
#
#    Estimate Percent renter-occupied housing units Occupied housing units MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS No cash rent
# 0                                                4.9
# 1                                                4.9
# 2                                                0.7
# 3                                                2.6
# 4                                                  -
#
# [5 rows x 277 columns]
